# %% [markdown]
# Name: Dalevinder Singh
#
# PI: F1067971

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import numpy as np
import csv
import os
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, datasets, metrics, Sequential, utils
from tensorflow.keras.layers import *
from IPython.display import HTML, display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Define Constants

# %%
data_dir = '/datasets/treesat'
label_level = 3

# %%
IMAGE_RESCALE = (288, 288)
input_shape = (IMAGE_RESCALE[0], IMAGE_RESCALE[1], 4)
batch_size = 128
label_key = f'level_{label_level}'

# %% [markdown]
# ## Load Data

# %%
train_file_labels = tf.data.experimental.make_csv_dataset(
    os.path.join(data_dir, 'train_file_labels.csv'), batch_size=batch_size, num_epochs=1)
train_file_labels = train_file_labels.unbatch()

# %%
validation_file_labels = tf.data.experimental.make_csv_dataset(
    os.path.join(data_dir, 'validation_file_labels.csv'), batch_size=batch_size, num_epochs=1)
validation_file_labels = validation_file_labels.unbatch()

# %%
test_file_labels = tf.data.experimental.make_csv_dataset(
    os.path.join(data_dir, 'test_file_labels.csv'), batch_size=batch_size, shuffle_buffer_size=1,
    num_epochs=1)
test_file_labels = test_file_labels.unbatch()

# %%
encoder_vocab_file = os.path.join(data_dir, f'level_{label_level}_vocabulary.txt')
label_encoder = StringLookup(vocabulary=encoder_vocab_file, num_oov_indices=0, output_mode='one_hot')

num_classes = len(label_encoder.get_vocabulary())

label_lookup = {i: n for i, n in enumerate(label_encoder.get_vocabulary())}
label_lookup
# Out:
# {0: 'japanese larch',
#  1: 'alder',
#  2: 'cleared',
#  3: 'european ash',
#  4: 'silver fir',
#  5: 'douglas fir',
#  6: 'poplar',
#  7: 'cherry',
#  8: 'weymouth pine',
#  9: 'norway spruce',
#  10: 'birch',
#  11: 'scots pine',
#  12: 'european larch',
#  13: 'english oak',
#  14: 'black pine',
#  15: 'linden',
#  16: 'sessile oak',
#  17: 'european beech',
#  18: 'red oak',
#  19: 'sycamore maple'}

# %% [markdown]
# ## Class Distribution

# %%
class_counts = train_file_labels.map(lambda fl: label_encoder(fl[label_key]))
class_counts = class_counts.reduce(tf.zeros((num_classes,)),
                             lambda o, l: tf.math.add(o, l))
class_counts
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([1234., 1824., 2844., 1816.,  687., 1896.,  331.,  223.,  371.,
#        4098., 1976., 4667.,  911., 2423.,  286.,  136., 1820., 4508.,
#        1272., 1943.], dtype=float32)>

# %%
# Plot distribution using class names
plt.figure(figsize=(10, 8))
plt.bar(label_encoder.get_vocabulary(), class_counts.numpy(), color='skyblue')
plt.xlabel("Class Names")
plt.ylabel("Count")
plt.title("Distribution of Unique Classes")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.show()  # Display the plotted distribution

# %% [markdown]
# ## Define Load Image and Add Weight Functions

# %%
# Adjusted load_image function to accept file_path and label separately
def load_image(file_path, label):
    # read the image from disk, decode it, resize it, and scale the pixels intensities to the range [0, 1]
    image = tf.io.read_file(file_path)
    image = tf.io.decode_png(image, channels=4)
    image = tf.image.resize(image, IMAGE_RESCALE)
    image /= 255.0
    
    # grab the label and encode it
    encoded_label = label_encoder(label)
    
    # return the image and the one-hot encoded label
    return image, encoded_label

# %%
# Function to add the weight to each image label pair
def add_weight(image, one_hot_label):
    label = tf.argmax(one_hot_label)
    return image, one_hot_label, class_weights[label]

# %% [markdown]
# ## Create Training, Validation and Test Data

# %%
train_data = train_file_labels.map(lambda fl: (fl['file_name'], fl[label_key]), 
                                      num_parallel_calls=tf.data.AUTOTUNE)
train_data = train_data.shuffle(200)
train_data = train_data.map(load_image, 
                                      num_parallel_calls=tf.data.AUTOTUNE)
train_data = train_data.batch(batch_size)
train_data = train_data.prefetch(tf.data.AUTOTUNE)

# %%
validation_data = validation_file_labels.map(lambda fl: (fl['file_name'], fl[label_key]), 
                                      num_parallel_calls=tf.data.AUTOTUNE)
validation_data = validation_data.map(load_image, 
                                      num_parallel_calls=tf.data.AUTOTUNE)
validation_data = validation_data.batch(batch_size)
validation_data = validation_data.prefetch(tf.data.AUTOTUNE)

# %%
test_data = test_file_labels.map(lambda fl: (fl['file_name'], fl[label_key]), 
                                      num_parallel_calls=tf.data.AUTOTUNE)

test_data = test_data.map(load_image, 
                                      num_parallel_calls=tf.data.AUTOTUNE)

test_data = test_data.batch(batch_size)
test_data = test_data.prefetch(tf.data.AUTOTUNE)

# Prevent any shuffling
test_data = test_data.shuffle(buffer_size=1)

# %% [markdown]
# ## Create Baseline Model

# %%
model_0 = Sequential([
    # input shape = (288,288,4)
    Conv2D(filters=8, kernel_size=(5, 5), padding='same', activation='relu', input_shape=input_shape),
    Conv2D(filters=8, kernel_size=(5, 5), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(rate=0.2), # output shape (144,144,8)

    Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(rate=0.2), # output shape (72,72,16)
    
    Conv2D(filters=24, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=24, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(rate=0.2), # output shape (36,36,24)
    
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(rate=0.2), # output shape (18,18,32)
   
    Flatten(),
    Dense(96, activation='relu'),
    Dropout(rate=0.5),
    Dense(num_classes, activation='softmax')
                 ])

model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 288, 288, 8)       808
#
#  conv2d_1 (Conv2D)           (None, 288, 288, 8)       1608
#
#  max_pooling2d (MaxPooling2  (None, 144, 144, 8)       0
#  D)
#
#  dropout (Dropout)           (None, 144, 144, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 144, 144, 16)      1168
#
#  conv2d_3 (Conv2D)           (None, 144, 144, 16)      2320
#
#  max_pooling2d_1 (MaxPoolin  (None, 72, 72, 16)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 72, 72, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 24)        3480
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 24)        5208
#
#  max_pooling2d_2 (MaxPoolin  (None, 36, 36, 24)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 36, 36, 24)        0
#
#  conv2d_6 (Conv2D)           (None, 36, 36, 32)        6944
#
#  max_pooling2d_3 (MaxPoolin  (None, 18, 18, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 18, 18, 32)        0
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 96)                995424
#
#  dropout_4 (Dropout)         (None, 96)                0
#
#  dense_1 (Dense)             (None, 20)                1940
#
# =================================================================
# Total params: 1018900 (3.89 MB)
# Trainable params: 1018900 (3.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_0.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
# Disable optimizer to prevent warning during training

# Retrieve the current configuration of the TensorFlow session
config = tf.config.optimizer.get_experimental_options()

# Set the layout optimizer to False to disable it
config['layout_optimizer'] = False

# Apply the new configuration
tf.config.optimizer.set_experimental_options(config)

# %%
# history = model_0.fit(
#     train_data,
#     epochs=25,
#     validation_data=validation_data,
#     verbose=0
# )

# %% [markdown]
# ## Cache Results

# %%
# # Save model
# model_0.save('baseline_l3.keras')

# # Save history
# with open('baseline_history_l3.json', 'w') as f:
#     json.dump(history.history, f)

# %%
# Load model
baseline_l3 = tf.keras.models.load_model('baseline_l3.keras')

# Load history
with open('baseline_history_l3.json') as f:
    baseline_history_l3 = json.load(f)

# %% [markdown]
# ## View Training

# %%
import matplotlib.pyplot as plt

# Assuming history contains the training history returned by model.fit
train_loss = baseline_history_l3['loss']
val_loss = baseline_history_l3['val_loss']
train_acc = baseline_history_l3['accuracy']
val_acc = baseline_history_l3['val_accuracy']

# Define number of epochs
epochs = range(1, len(train_acc)+1)

# Plot accuracy
plt.plot(epochs, train_acc, label='Train Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluate the Model

# %%
baseline_l3.evaluate(test_data, return_dict=True)
# Out:
# 79/79 [==============================] - 26s 282ms/step - loss: 1.7849 - accuracy: 0.4452
# {'loss': 1.7848531007766724, 'accuracy': 0.44517216086387634}

# %%
test_predictions = baseline_l3.predict(test_data)
# Out:
# 79/79 [==============================] - 22s 278ms/step

# %%
predict_labels = np.argmax(test_predictions, axis=1)

# %%
test_labels = np.array(list(test_data.unbatch().map(lambda x, y: y).as_numpy_iterator()))
test_labels = np.argmax(test_labels, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm = tf.math.confusion_matrix(test_labels, predict_labels).numpy()
cm
# Out:
# array([[  45,   13,    2,    3,    8,   45,    0,    0,    0,   10,   29,
#          147,    0,    5,    8,    0,    0,   26,    0,    2],
#        [  13,   76,   24,    4,    7,   10,    0,    0,    0,   22,   33,
#           95,    0,   33,    0,    0,    4,  143,    3,   14],
#        [   1,    8,  713,    0,    2,    3,    0,    0,    0,   31,   11,
#           15,    0,   10,    1,    0,    0,   90,    1,    1],
#        [   2,   10,    6,   27,    0,    3,    0,    0,    0,    8,   11,
#           11,    0,   88,    0,    0,    8,  344,    8,   19],
#        [   9,    6,    0,    0,   36,   55,    0,    0,    0,   12,    8,
#           28,    0,    2,   10,    0,    0,   24,    0,    0],
#        [   7,    4,   11,    3,    8,  204,    0,    0,    1,   92,    8,
#          163,    0,    8,    2,    0,    0,   30,    0,    1],
#        [   2,    4,    3,    0,    0,    0,    0,    0,    0,    3,    6,
#            5,    0,   20,    0,    0,    2,   36,    0,    0],
#        [   0,    3,    3,    0,    0,    0,    0,    0,    0,    3,    1,
#            3,    0,    6,    0,    0,    1,   25,    1,    4],
#        [   6,    1,    0,    0,    2,   18,    0,    0,    0,    4,    1,
#           34,    0,    1,    6,    0,    0,    2,    0,    0],
#        [   0,   14,   36,    2,    2,   45,    0,    0,    0,  826,    7,
#          126,    0,    4,    5,    0,    0,   73,    0,    4],
#        [  24,   34,   42,    9,    3,   18,    0,    0,    0,   24,   77,
#          111,    2,   59,    1,    0,    9,  136,    8,   11],
#        [  17,   53,    8,    3,    3,   49,    0,    0,    1,   35,   17,
#         1014,    2,   20,    8,    0,    0,   44,    2,    7],
#        [   5,   20,    4,    2,    5,   16,    0,    0,    0,   49,    5,
#          135,    2,    1,    1,    0,    0,   46,    0,    3],
#        [   3,    5,   16,    7,    2,    5,    0,    0,    0,    9,   20,
#           18,    0,  304,    1,    0,    7,  249,   17,    3],
#        [   2,    1,    3,    3,    0,    2,    0,    0,    0,    4,    0,
#           16,    0,    8,   47,    0,    0,   10,    0,    2],
#        [   0,    3,    0,    1,    0,    0,    0,    0,    0,    1,    0,
#            4,    0,   10,    0,    0,    0,   29,    0,    4],
#        [   2,    9,   12,   13,    0,    0,    0,    0,    0,    8,   12,
#           10,    0,  196,    1,    0,   21,  207,   20,    9],
#        [   5,   31,   43,    4,    0,    1,    0,    0,    0,   41,   21,
#           15,    0,   76,    0,    0,    2, 1013,    8,   13],
#        [   3,    3,   16,    0,    1,    2,    0,    0,    0,    1,   17,
#           12,    0,  118,    0,    0,    6,  139,   59,    4],
#        [   1,   17,   36,   18,    0,    3,    0,    0,    0,   24,   25,
#           25,    0,   83,    0,    0,    1,  346,    3,   22]],
#       dtype=int32)

# %%
def pretty_cm(cm):
    result_table  = '<h3>Confusion matrix</h3>\n'
    result_table += '<table border=1>\n'
    result_table += f'<tr><td>&nbsp;</td><td>&nbsp;</td><th colspan={len(label_lookup)}>Predicted labels</th></tr>\n'
    result_table += '<tr><td>&nbsp;</td><td>&nbsp;</td>'

    for _, cn in sorted(label_lookup.items()):
        result_table += f'<td><strong>{cn}</strong></td>'
    result_table += '</tr>\n'

    result_table += '<tr>\n'
    result_table += f'<th rowspan={len(label_lookup) + 1}>Actual labels</th>\n'

    for ai, an in sorted(label_lookup.items()):
        result_table += '<tr>\n'
        result_table += f'  <td><strong>{an}</strong></td>\n'
        for pi, pn in sorted(label_lookup.items()):
            result_table += f'  <td>{cm[ai, pi]}</td>\n'
        result_table += '</tr>\n'
    result_table += "</table>"
    # print(result_table)
    display(HTML(result_table))

# %%
pretty_cm(cm)
# Out:
# <h3>Confusion matrix</h3>
# <table border=1>
# <tr><td>&nbsp;</td><td>&nbsp;</td><th colspan=20>Predicted labels</th></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td><strong>japanese larch</strong></td><td><strong>alder</strong></td><td><strong>cleared</strong></td><td><strong>european ash</strong></td><td><strong>silver fir</strong></td><td><strong>douglas fir</strong></td><td><strong>poplar</strong></td><td><strong>cherry</strong></td><td><strong>weymouth pine</strong></td><td><strong>norway spruce</strong></td><td><strong>birch</strong></td><td><strong>scots pine</strong></td><td><strong>european larch</strong></td><td><strong>english oak</strong></td><td><strong>black pine</strong></td><td><strong>linden</strong></td><td><strong>sessile oak</strong></td><td><strong>european beech</strong></td><td><strong>red oak</strong></td><td><strong>sycamore maple</strong></td></tr>
# <tr>
# <th rowspan=21>Actual labels</th>
# <tr>
#   <td><strong>japanese larch</strong></td>
#   <td>45</td>
#   <td>13</td>
#   <td>2</td>
#   <td>3</td>
#   <td>8</td>
#   <td>45</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>10</td>
#   <td>29</td>
#   <td>147</td>
#   <td>0</td>
#   <td>5</td>
#   <td>8</td>
#   <td>0</td>
#   <td>0</td>
#   <td>26</td>
#   <td>0</td>
#   <td>2</td>
# </tr>
# <tr>
#   <td><strong>alder</strong></td>
#   <td>13</td>
#   <td>76</td>
#   <td>24</td>
#   <td>4</td>
#   <td>7</td>
#   <td>10</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>22</td>
#   <td>33</td>
#   <td>95</td>
#   <td>0</td>
#   <td>33</td>
#   <td>0</td>
#   <td>0</td>
#   <td>4</td>
#   <td>143</td>
#   <td>3</td>
#   <td>14</td>
# </tr>
# <tr>
#   <td><strong>cleared</strong></td>
#   <td>1</td>
#   <td>8</td>
#   <td>713</td>
#   <td>0</td>
#   <td>2</td>
#   <td>3</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>31</td>
#   <td>11</td>
#   <td>15</td>
#   <td>0</td>
#   <td>10</td>
#   <td>1</td>
#   <td>0</td>
#   <td>0</td>
#   <td>90</td>
#   <td>1</td>
#   <td>1</td>
# </tr>
# <tr>
#   <td><strong>european ash</strong></td>
#   <td>2</td>
#   <td>10</td>
#   <td>6</td>
#   <td>27</td>
#   <td>0</td>
#   <td>3</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>8</td>
#   <td>11</td>
#   <td>11</td>
#   <td>0</td>
#   <td>88</td>
#   <td>0</td>
#   <td>0</td>
#   <td>8</td>
#   <td>344</td>
#   <td>8</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td><strong>silver fir</strong></td>
#   <td>9</td>
#   <td>6</td>
#   <td>0</td>
#   <td>0</td>
#   <td>36</td>
#   <td>55</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>12</td>
#   <td>8</td>
#   <td>28</td>
#   <td>0</td>
#   <td>2</td>
#   <td>10</td>
#   <td>0</td>
#   <td>0</td>
#   <td>24</td>
#   <td>0</td>
#   <td>0</td>
# </tr>
# <tr>
#   <td><strong>douglas fir</strong></td>
#   <td>7</td>
#   <td>4</td>
#   <td>11</td>
#   <td>3</td>
#   <td>8</td>
#   <td>204</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>92</td>
#   <td>8</td>
#   <td>163</td>
#   <td>0</td>
#   <td>8</td>
#   <td>2</td>
#   <td>0</td>
#   <td>0</td>
#   <td>30</td>
#   <td>0</td>
#   <td>1</td>
# </tr>
# <tr>
#   <td><strong>poplar</strong></td>
#   <td>2</td>
#   <td>4</td>
#   <td>3</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>3</td>
#   <td>6</td>
#   <td>5</td>
#   <td>0</td>
#   <td>20</td>
#   <td>0</td>
#   <td>0</td>
#   <td>2</td>
#   <td>36</td>
#   <td>0</td>
#   <td>0</td>
# </tr>
# <tr>
#   <td><strong>cherry</strong></td>
#   <td>0</td>
#   <td>3</td>
#   <td>3</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>3</td>
#   <td>1</td>
#   <td>3</td>
#   <td>0</td>
#   <td>6</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>25</td>
#   <td>1</td>
#   <td>4</td>
# </tr>
# <tr>
#   <td><strong>weymouth pine</strong></td>
#   <td>6</td>
#   <td>1</td>
#   <td>0</td>
#   <td>0</td>
#   <td>2</td>
#   <td>18</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>4</td>
#   <td>1</td>
#   <td>34</td>
#   <td>0</td>
#   <td>1</td>
#   <td>6</td>
#   <td>0</td>
#   <td>0</td>
#   <td>2</td>
#   <td>0</td>
#   <td>0</td>
# </tr>
# <tr>
#   <td><strong>norway spruce</strong></td>
#   <td>0</td>
#   <td>14</td>
#   <td>36</td>
#   <td>2</td>
#   <td>2</td>
#   <td>45</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>826</td>
#   <td>7</td>
#   <td>126</td>
#   <td>0</td>
#   <td>4</td>
#   <td>5</td>
#   <td>0</td>
#   <td>0</td>
#   <td>73</td>
#   <td>0</td>
#   <td>4</td>
# </tr>
# <tr>
#   <td><strong>birch</strong></td>
#   <td>24</td>
#   <td>34</td>
#   <td>42</td>
#   <td>9</td>
#   <td>3</td>
#   <td>18</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>24</td>
#   <td>77</td>
#   <td>111</td>
#   <td>2</td>
#   <td>59</td>
#   <td>1</td>
#   <td>0</td>
#   <td>9</td>
#   <td>136</td>
#   <td>8</td>
#   <td>11</td>
# </tr>
# <tr>
#   <td><strong>scots pine</strong></td>
#   <td>17</td>
#   <td>53</td>
#   <td>8</td>
#   <td>3</td>
#   <td>3</td>
#   <td>49</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>35</td>
#   <td>17</td>
#   <td>1014</td>
#   <td>2</td>
#   <td>20</td>
#   <td>8</td>
#   <td>0</td>
#   <td>0</td>
#   <td>44</td>
#   <td>2</td>
#   <td>7</td>
# </tr>
# <tr>
#   <td><strong>european larch</strong></td>
#   <td>5</td>
#   <td>20</td>
#   <td>4</td>
#   <td>2</td>
#   <td>5</td>
#   <td>16</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>49</td>
#   <td>5</td>
#   <td>135</td>
#   <td>2</td>
#   <td>1</td>
#   <td>1</td>
#   <td>0</td>
#   <td>0</td>
#   <td>46</td>
#   <td>0</td>
#   <td>3</td>
# </tr>
# <tr>
#   <td><strong>english oak</strong></td>
#   <td>3</td>
#   <td>5</td>
#   <td>16</td>
#   <td>7</td>
#   <td>2</td>
#   <td>5</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>9</td>
#   <td>20</td>
#   <td>18</td>
#   <td>0</td>
#   <td>304</td>
#   <td>1</td>
#   <td>0</td>
#   <td>7</td>
#   <td>249</td>
#   <td>17</td>
#   <td>3</td>
# </tr>
# <tr>
#   <td><strong>black pine</strong></td>
#   <td>2</td>
#   <td>1</td>
#   <td>3</td>
#   <td>3</td>
#   <td>0</td>
#   <td>2</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>4</td>
#   <td>0</td>
#   <td>16</td>
#   <td>0</td>
#   <td>8</td>
#   <td>47</td>
#   <td>0</td>
#   <td>0</td>
#   <td>10</td>
#   <td>0</td>
#   <td>2</td>
# </tr>
# <tr>
#   <td><strong>linden</strong></td>
#   <td>0</td>
#   <td>3</td>
#   <td>0</td>
#   <td>1</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>0</td>
#   <td>4</td>
#   <td>0</td>
#   <td>10</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>29</td>
#   <td>0</td>
#   <td>4</td>
# </tr>
# <tr>
#   <td><strong>sessile oak</strong></td>
#   <td>2</td>
#   <td>9</td>
#   <td>12</td>
#   <td>13</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>8</td>
#   <td>12</td>
#   <td>10</td>
#   <td>0</td>
#   <td>196</td>
#   <td>1</td>
#   <td>0</td>
#   <td>21</td>
#   <td>207</td>
#   <td>20</td>
#   <td>9</td>
# </tr>
# <tr>
#   <td><strong>european beech</strong></td>
#   <td>5</td>
#   <td>31</td>
#   <td>43</td>
#   <td>4</td>
#   <td>0</td>
#   <td>1</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>41</td>
#   <td>21</td>
#   <td>15</td>
#   <td>0</td>
#   <td>76</td>
#   <td>0</td>
#   <td>0</td>
#   <td>2</td>
#   <td>1013</td>
#   <td>8</td>
#   <td>13</td>
# </tr>
# <tr>
#   <td><strong>red oak</strong></td>
#   <td>3</td>
#   <td>3</td>
#   <td>16</td>
#   <td>0</td>
#   <td>1</td>
#   <td>2</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>17</td>
#   <td>12</td>
#   <td>0</td>
#   <td>118</td>
#   <td>0</td>
#   <td>0</td>
#   <td>6</td>
#   <td>139</td>
#   <td>59</td>
#   <td>4</td>
# </tr>
# <tr>
#   <td><strong>sycamore maple</strong></td>
#   <td>1</td>
#   <td>17</td>
#   <td>36</td>
#   <td>18</td>
#   <td>0</td>
#   <td>3</td>
#   <td>0</td>
#   <td>0</td>
#   <td>0</td>
#   <td>24</td>
#   <td>25</td>
#   <td>25</td>
#   <td>0</td>
#   <td>83</td>
#   <td>0</td>
#   <td>0</td>
#   <td>1</td>
#   <td>346</td>
#   <td>3</td>
#   <td>22</td>
# </tr>
# </table>
